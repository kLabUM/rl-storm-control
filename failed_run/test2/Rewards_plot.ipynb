# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
rewards = np.empty([0])
for i in [3, 4, 6, 7, 8, 9, 10, 11]:
    rewards = np.append(rewards, np.load("mean_rewardsprof_x_7_"+str(i)+".h5.npy"))

# %%
plt.plot(rewards)
plt.show()
